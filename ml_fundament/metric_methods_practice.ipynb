# %% [markdown]
# <center><img src="./images/nup_logo_dark.jpeg" width=300 style="display: inline-block;"></center>
#
# ## Fundamentals of ML
# ### Metric methods practice
#
# <br />

# %% [markdown]
# ### Import libraries

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Obtaining dependency information for mlxtend from https://files.pythonhosted.org/packages/1c/07/512f6a780239ad6ce06ce2aa7b4067583f5ddcfc7703a964a082c706a070/mlxtend-0.23.1-py3-none-any.whl.metadata
#   Downloading mlxtend-0.23.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in /Users/Aleksandr.Avdiushenko/PycharmProjects/IOAI_project/.venv/lib/python3.11/site-packages (from mlxtend) (1.14.0)
# Requirement already satisfied: numpy>=1.16.2 in /Users/Aleksandr.Avdiushenko/PycharmProjects/IOAI_project/.venv/lib/python3.11/site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in /Users/Aleksandr.Avdiushenko/PycharmProjects/IOAI_project/.venv/lib/python3.11/site-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in /Users/Aleksandr.Avdiushenko/PycharmProjects/IOAI_project/.venv/lib/python3.11/site-packages (from mlxtend) (1.5.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /Users/Aleksandr.Avdiushenko/PycharmProjects/IOAI_project/.venv/lib/python3.11/site-packages (from mlxtend) (3.9.1)
# Requirement already satisfied: joblib>=0.13.2 in /Users/Aleksandr.Avdiushenko/PycharmProjects/IOAI_project/.venv/lib/python3.11/site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/Aleksandr.Avdiushenko/PycharmProjects/IOAI_project/.venv/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/Aleksandr.Avdiushenko/PycharmProjects/IOAI_project/.venv/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/Aleksandr.Avdiushenko/PycharmProjects/IOAI_project/.venv/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/Aleksandr.Avdiushenko/PycharmProjects/IOAI_project/.venv/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/Aleksandr.Avdiushenko/PycharmProjects/IOAI_project/.venv/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/Aleksandr.Avdiushenko/PycharmProjects/IOAI_project/.venv/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/Aleksandr.Avdiushenko/PycharmProjects/IOAI_project/.venv/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/Aleksandr.Avdiushenko/PycharmProjects/IOAI_project/.venv/lib/python3.11/site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/Aleksandr.Avdiushenko/PycharmProjects/IOAI_project/.venv/lib/python3.11/site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/Aleksandr.Avdiushenko/PycharmProjects/IOAI_project/.venv/lib/python3.11/site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/Aleksandr.Avdiushenko/PycharmProjects/IOAI_project/.venv/lib/python3.11/site-packages (from scikit-learn>=1.0.2->mlxtend) (3.5.0)
# Requirement already satisfied: six>=1.5 in /Users/Aleksandr.Avdiushenko/PycharmProjects/IOAI_project/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Downloading mlxtend-0.23.1-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 4.9 MB/s eta 0:00:00a 0:00:010m
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.1
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import numpy as np

from mlxtend.plotting import plot_decision_regions
from sklearn.model_selection import train_test_split

np.random.seed(42)

# %% [markdown]
# Load the dataset:

# %%
from sklearn.datasets import load_iris
X, y = load_iris(return_X_y=True)

X = X[:, 2:4]
features = np.array(["petal length", "petal width"])

labels = np.array(["setosa", "versicolor", "virginica"])

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=30, 
                                                    random_state=10)

# %%
X_train.shape, X_test.shape
# Out:
# ((120, 2), (30, 2))

# %%
y_train
# Out:
# array([1, 1, 2, 2, 2, 0, 2, 2, 2, 2, 0, 0, 1, 0, 1, 0, 1, 1, 2, 2, 1, 2,
#        1, 1, 1, 0, 0, 1, 0, 2, 0, 0, 2, 1, 2, 0, 2, 0, 1, 1, 0, 2, 2, 2,
#        2, 2, 0, 1, 2, 1, 0, 2, 1, 1, 0, 0, 0, 1, 2, 2, 1, 0, 0, 0, 2, 2,
#        1, 1, 2, 2, 2, 2, 1, 0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 1, 0, 1, 0, 1,
#        2, 0, 1, 1, 2, 0, 2, 0, 1, 1, 2, 2, 0, 1, 2, 2, 1, 1, 2, 0, 2, 0,
#        0, 1, 0, 2, 2, 2, 1, 0, 2, 0])

# %% [markdown]
# Create a linear regressor (without regularization):

# %%
def show_legend():
    cb = plt.colorbar()
    loc = [0, 1, 2]
    cb.set_ticks(loc)
    cb.set_ticklabels(labels)

# %%
plt.figure(figsize=(18.0, 10.0))
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, s=200, cmap='autumn', edgecolors="black")
plt.xlabel(features[0])
plt.ylabel(features[1])
show_legend()

# %%
plt.figure(figsize=(18.0, 10.0))
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, s=200, cmap='autumn', edgecolors="black")
plt.xlabel(features[0])
plt.ylabel(features[1])
show_legend()

# %% [markdown]
# ### K-nearest neighbors classifier (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors=1)
_ = model.fit(X_train, y_train)

# %%
from matplotlib.gridspec import GridSpec

fig, gs = plt.figure(figsize=(18, 8)), GridSpec(1, 2)

ax = []
for i in range(2):
    ax.append(fig.add_subplot(gs[i]))


plot_decision_regions(X_train, y_train, model, ax=ax[0])
plot_decision_regions(X_test, y_test, model, ax=ax[1])

plt.show()

# %%
models = []
for n_neighbors in range(1, 121):
    model = KNeighborsClassifier(n_neighbors=n_neighbors)
    model.fit(X_train, y_train)
    models.append(model)

# %% [markdown]
# ### Question 1: Which $k$ to choose?

# %%
fig, gs = plt.figure(figsize=(18,4)), GridSpec(1, 4)

ax = []
for i in range(4):
    ax.append(fig.add_subplot(gs[i]))

for i in range(4):
    plot_decision_regions(X_test, y_test, models[i], ax=ax[i])

plt.show()

# %%
fig, gs = plt.figure(figsize=(18,4)), GridSpec(1, 4)

ax = []
for i in range(4):
    ax.append(fig.add_subplot(gs[i]))

for i in range(4):
    plot_decision_regions(X_test, y_test, models[30*i + 28], ax=ax[i])

plt.show()

# %% [markdown]
# ### Linearly Decreasing Weights

# %%
def lin_weights(distance):
    print(distance.shape)
    ret = np.ones_like(distance)
    k = ret.shape[1]
    for i in range(k):
        ret[:, i] *= (k-i)/k
    return ret

# %% [markdown]
# ### Question 2: What will change with linearly decreasing weights? Which $k$ is reasonable to choose now?

# %%
models = []
for n_neighbors in range(1, 121):
    model = KNeighborsClassifier(n_neighbors=n_neighbors, 
                                 weights=lin_weights)
    model.fit(X_train, y_train)
    models.append(model)

# %%
# %%time
fig, gs = plt.figure(figsize=(18,4)), GridSpec(1, 4)

ax = []
for i in range(4):
    ax.append(fig.add_subplot(gs[i]))

for i in range(4):
    plot_decision_regions(X_test, y_test, models[i], ax=ax[i], zoom_factor=1)

plt.show()
# Out:
# (720000, 1)
# (720000, 2)
# (720000, 3)
# (720000, 4)
# CPU times: total: 1.84 s
# Wall time: 4.03 s

# %% [markdown]
# ### Why we got 720000 above?

# %%
from math import floor, ceil

X = X_test
x_index, y_index = 0, 1
zoom_factor = 2
# from plot_decision_regions source
x_min, x_max = (
    X[:, x_index].min() - 1.0 / zoom_factor,
    X[:, x_index].max() + 1.0 / zoom_factor,
)
y_min, y_max = (
    X[:, y_index].min() - 1.0 / zoom_factor,
    X[:, y_index].max() + 1.0 / zoom_factor,
)

fig, gs = plt.figure(figsize=(18,4)), GridSpec(1, 4)
xnum, ynum = plt.gcf().dpi * plt.gcf().get_size_inches()
xnum, ynum = floor(xnum), ceil(ynum)
print(f"xnum={xnum}, ynum={ynum}, xnum*ynum={xnum*ynum}")
xx, yy = np.meshgrid(
    np.linspace(x_min, x_max, num=xnum), np.linspace(y_min, y_max, num=ynum)
)
X_grid = np.array([xx.ravel(), yy.ravel()]).T
print(X_grid.shape)

X_predict = np.zeros((X_grid.shape[0], 2))
X_predict[:, x_index] = X_grid[:, 0]
X_predict[:, y_index] = X_grid[:, 1]
print(X_predict.shape)

clf = models[1]
Z = clf.predict(X_predict.astype(X.dtype))
Z = Z.reshape(xx.shape)
print(Z.shape)
# Out:
# xnum=1800, ynum=400, xnum*ynum=720000
# (720000, 2)
# (720000, 2)
# (720000, 2)
# (400, 1800)

# %%
# %%time
fig, gs = plt.figure(figsize=(18,4)), GridSpec(1, 4)

ax = []
for i in range(4):
    ax.append(fig.add_subplot(gs[i]))

for i in range(4):
    plot_decision_regions(X_test, y_test, models[30 * i + 28], ax=ax[i])

plt.show()
# Out:
# (720000, 29)
# (720000, 59)
# (720000, 89)
# (720000, 119)
# CPU times: total: 15 s
# Wall time: 27.1 s

# %% [markdown]
# ### Parzen Window Method

# %%
def K(distance, h=0.05):
    ret = np.array(distance) / h
    return (1 - ret**2) * (np.abs(ret) <= 1)

# %% [markdown]
# ### Question 3: What value is reasonable to choose for $h$?

# %%
fig, gs = plt.figure(figsize=(19,4)), GridSpec(1, 4)

ax = []
for i, h in enumerate([0.05, 0.1, 0.2, 0.5]):
    model = KNeighborsClassifier(n_neighbors=len(X_train),
                                 weights=lambda x: K(x, h=h))
    model.fit(X_train, y_train)
    ax.append(fig.add_subplot(gs[i]))
    plot_decision_regions(X_test, y_test, model, ax=ax[i])

plt.show()

# %%
fig, gs = plt.figure(figsize=(19,4)), GridSpec(1, 4)

ax = []
for i, h in enumerate([1.0, 5.0, 10.0, 20.0]):
    model = KNeighborsClassifier(n_neighbors=len(X_train),
                                 weights=lambda x: K(x, h=h))
    model.fit(X_train, y_train)
    ax.append(fig.add_subplot(gs[i]))
    plot_decision_regions(X_test, y_test, model, ax=ax[i])

plt.show()

# %% [markdown]
# ### Potential Function Method

# %%
y_new_train = y_train.copy()
y_new_train[y_new_train == 2] = 0

y_new_test = y_test.copy()
y_new_test[y_new_test == 2] = 0

# %% [markdown]
# #### Let's implement the Potential Function Method!

# %%
from scipy.spatial.distance import cdist

# Potential Functions Method
class PFM(object):
    def __init__(self, kernel=None):
        self.X, self.Y, self.gams = None, None, None
        self.kernel = lambda x: np.ones_like(x)
        if kernel is not None:
            self.kernel = kernel
    
    def scores(self, X):
        features = self.gams * self.kernel(cdist(X, self.X))
        scores = np.vstack(
            [np.sum(features.T[np.where(self.Y == 0)].T, axis=-1),
             np.sum(features.T[np.where(self.Y == 1)].T, axis=-1)]).T
        return scores
    
    def predict(self, X):
        return np.argmax(self.scores(X), axis=-1)
    
    def fit(self, X, Y, epoch=5):
        self.X, self.Y, self.gams = np.array(X), np.array(Y), np.zeros_like(Y) # what if np.ones_like(Y)?
        for _ in range(epoch):
            for i, (x, y) in enumerate(zip(self.X, self.Y)):
                # question on the understanding of code — explain the following line:
                if self.predict(np.array([x]))[0] != y:
                    self.gams[i] += 1

# %% [markdown]
# ### Question 4: If the weights and action radii are equal, is it possible to express the potential method through the Parzen window?

# %%
# def K(distance, h=0.05):
#     ret = np.array(distance)/h
#     return (1 - ret**2) * (np.abs(ret) <= 1)

# %%
epochs = [1, 5]
fig, gs = plt.figure(figsize=(19,4)), GridSpec(1, len(epochs))

ax = []
for i, epoch in enumerate(epochs):
    model = PFM(kernel=lambda r: 1 / (r + 1e-5))
    model.fit(X_train, y_new_train, epoch)
    ax.append(fig.add_subplot(gs[i]))
    plot_decision_regions(X_test, y_new_test, model, ax=ax[i])

plt.show()

# %% [markdown]
# ### Nadaraya-Watson Estimator

# %%
l = 150

# data generation
x = np.linspace(0, 30, num=l)
Y_without_noise = x + 4 * np.sin(x)
Y = Y_without_noise + 4 * np.random.randn(l)

# features generation
X = np.vstack([np.ones_like(x), x, np.sin(x)]).T

# %%
fig, ax = plt.subplots()

fig.set_size_inches(18.0, 10.0)

plt.plot(x, Y, '.')

ax.set_xlabel('x')
ax.set_ylabel('y')

plt.show()

# %%
class NWE(object):
    def __init__(self, kernel=None):
        self.X, self.Y = None, None
        self.kernel = lambda x: np.ones_like(x)
        if kernel is not None:
            self.kernel = kernel
            
    def predict(self, X):
        features = np.sum(self.Y * self.kernel(cdist(X, self.X)), axis=-1)
        return features / (np.sum(self.kernel(cdist(X, self.X)), axis=-1) + 1e-5)
    
    def fit(self, X, Y):
        self.X, self.Y = np.array(X), np.array(Y)

# %%
def K(distance, h=2):
    ret = np.array(distance)/h
    return (1 - ret**2) * (np.abs(ret) <= 1)

# %%
model = NWE(kernel=lambda x: K(x, h=1))
model.fit(X, Y)

# %%
plt.figure(figsize=(18.0, 10.0))
plt.plot(x, Y, '.', label='points')
plt.plot(x, Y_without_noise, label='real')
plt.plot(x, model.predict(X), label='predict')

plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Question 5: Suggest how to make the approximation more accurate? Smoother? How do you think the generalization ability of the regression will improve or worsen with these changes?
